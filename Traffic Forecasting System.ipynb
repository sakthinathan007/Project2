# %%
# %run traf.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\traffic.py:55
#      47     p15 = int(row["pred_15min"]) + random.randint(-5, 5)
#      49     return {
#      50         "5_min": max(0, p5),
#      51         "10_min": max(0, p10),
#      52         "15_min": max(0, p15)
#      53     }
# ---> 55 actual = int(row["pred_5min"])   # actual value from dataset
#      56 predicted = p5                  # your predicted value
#      58 error, accuracy = calculate_single_accuracy(actual, predicted)
#
# NameError: name 'row' is not defined
