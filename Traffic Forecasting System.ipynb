# %%
# %run traffic.py
# Out:
# ✅ Dataset loaded successfully (10 rows)
#
# 📌 Available Locations:
# 1. MG Road (Bengaluru)
# 2. Anna Nagar (Chennai)
# 3. T. Nagar (Chennai)
# 4. ECR Highway (Chennai)
# 5. Silk Board Junction (Bengaluru)
# 6. Koyambedu Junction (Chennai)
# 7. Besant Nagar (Chennai)
# 8. Whitefield (Bengaluru)
# 9. Velachery (Chennai)
# 10. Marathahalli (Bengaluru)
# Enter location (or 'q' to quit):  Besant Nagar
# ...
# 📍 Besant Nagar (Chennai)
# ...
#
# 🔮 Predictions:
#   +5 min  : 122 → Moderate Traffic
#   +10 min : 121 → Moderate Traffic
#   +15 min : 115 → Moderate Traffic
#
# ⚠️ Suggestion:
#  You may try Ring Road to save time
#
# 📊 Live Status:
#   Vehicles : 103
#   Speed    : 43 km/h
#   Status   : Moderate Traffic
#   Event    : None
# Enter location (or 'q' to quit):  ECR Highway
# ...
# 📍 ECR Highway (Chennai)
# ...
#
# 🔮 Predictions:
#   +5 min  : 170 → Moderate Traffic
#   +10 min : 188 → Heavy Traffic
#   +15 min : 183 → Heavy Traffic
#
# 🚨 Alert:
#  Heavy traffic expected in ECR Highway
#
# ...
