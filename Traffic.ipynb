# %%
# %run traffic.py
# Out:
# Available Locations:
#   - MG Road (Bengaluru)
#   - Anna Nagar (Chennai)
#   - T. Nagar (Chennai)
#   - ECR Highway (Chennai)
#   - Silk Board Junction (Bengaluru)
#   - Koyambedu Junction (Chennai)
#   - Besant Nagar (Chennai)
#   - Whitefield (Bengaluru)
#   - Velachery (Chennai)
#   - Marathahalli (Bengaluru)
# Enter location name (or 'all' / 'q'):  anna nagar
# ...
# 📍 Anna Nagar (Chennai)
# ...
#
# 🔮 Prediction:
#   +5 min  : 133 → Heavy Traffic
#   +10 min : 145 → Heavy Traffic
#   +15 min : 140 → Heavy Traffic
#
# 🚨 Alert:
#   Heavy Traffic
#
# 🛣️ Recommendation:
#   Use Poonamallee High Road to avoid congestion
#
# 📊 Live Status:
#   Vehicles : 134
#   Speed    : 32 km/h
#   Status   : Heavy Traffic
#
# 📈 Summary:
#   Traffic is currently Heavy Traffic and expected to remain Heavy Traffic.
# ...
# Enter location name (or 'all' / 'q'):  ECR Highway
# ...
# 📍 ECR Highway (Chennai)
# ...
#
# 🔮 Prediction:
#   +5 min  : 166 → Heavy Traffic
#   +10 min : 181 → Heavy Traffic
#   +15 min : 176 → Heavy Traffic
# ...
